# %%
from pylab import mpl, plt
plt.style.use('seaborn')
mpl.rcParams['savefig.dpi']=300
mpl.rcParams['font.family']='serif'

# %%
import configparser
c = configparser.ConfigParser()
c.read('../pyalgo.cfg')
# Out:
# []

# %%
import quandl as q
q.ApiConfig.api_key = "R6pNyUjrQriCrZtuus9K"
mydata = q.get("BCHAIN/MKPRU")
mydata['Moving Average'] = mydata['Value'].rolling(100).mean()
mydata.loc['2020-1-1':].plot(title='BTC/USD exchange rate',figsize=(10,6))

# %%
data=q.get('FSE/SAP_X',start_date='2018-1-1')

# %%
data
# Out:
#               Open    High     Low   Close Change  Traded Volume  \
# Date
# 2018-01-02   93.35   93.95   92.12   92.80   None      2334984.0
# 2018-01-03   93.00   94.65   92.63   94.07   None      2346852.0
# 2018-01-11     NaN   93.74   91.04   91.43   None      4274991.0
# 2018-01-12     NaN   91.47   90.27   90.73   None      3437210.0
# 2018-01-15     NaN   90.61   89.71   90.06   None      2053812.0
# ...            ...     ...     ...     ...    ...            ...
# 2020-11-25   97.70   99.20   97.50   99.04   None        14786.0
# 2020-11-26   99.20  100.52   98.81   99.74   None        15074.0
# 2020-11-27   99.81  100.74   99.60  100.10   None        10634.0
# 2020-11-30   99.90  101.74   99.90  101.70   None        12624.0
# 2020-12-01  102.90  102.90  101.76  101.90   None        15426.0
#
#                 Turnover Last Price of the Day Daily Traded Units  \
# Date
# 2018-01-02  2.165717e+08                  None               None
# ...
