# %%
import requests
import pandas as pd

# %%
API_KEY = "fcd13b16706c8b961be0641aebd0f143-285a7112c2a5ec5c8ecd2082de590867"
ACCOUNT_ID = "101-004-19105515-001"
OANDA_URL = 'https://api-fxpractice.oanda.com/v3'

SECURE_HEADER = {
    'Authorization': f'Bearer {API_KEY}'
}

# %%
session = requests.Session()

# %%
ACCOUNT_ID
# Out:
# '101-004-19105515-001'

# %%
count = 10
granularity = "H1"

# %%
instrument = "EUR_USD"

# %%
url = f"{OANDA_URL}/accounts/{ACCOUNT_ID}/instruments"
url
# Out:
# 'https://api-fxpractice.oanda.com/v3/accounts/101-004-19105515-001/instruments'

# %%
params = dict(
    count = count,
    granularity = granularity,
    price = "MBA"
)

# %%
params
# Out:
# {'count': 10, 'granularity': 'H1', 'price': 'MBA'}

# %%
response=session.get(url, params = None, headers = SECURE_HEADER)

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()

# %%
data
# Out:
# {'instruments': [{'name': 'XAG_EUR',
#    'type': 'METAL',
#    'displayName': 'Silver/EUR',
#    'pipLocation': -4,
#    'displayPrecision': 5,
#    'tradeUnitsPrecision': 0,
#    'minimumTradeSize': '1',
#    'maximumTrailingStopDistance': '1.00000',
#    'minimumTrailingStopDistance': '0.00050',
#    'maximumPositionSize': '0',
#    'maximumOrderUnits': '500000',
#    'marginRate': '0.10',
#    'guaranteedStopLossOrderMode': 'DISABLED',
#    'tags': [{'type': 'KID_ASSET_CLASS', 'name': 'METAL'},
#     {'type': 'ASSET_CLASS', 'name': 'COMMODITY'}],
#    'financing': {'longRate': '-0.007',
#     'shortRate': '-0.0154',
#     'financingDaysOfWeek': [{'dayOfWeek': 'MONDAY', 'daysCharged': 1},
#      {'dayOfWeek': 'TUESDAY', 'daysCharged': 1},
#      {'dayOfWeek': 'WEDNESDAY', 'daysCharged': 1},
#      {'dayOfWeek': 'THURSDAY', 'daysCharged': 1},
#      {'dayOfWeek': 'FRIDAY', 'daysCharged': 1},
#      {'dayOfWeek': 'SATURDAY', 'daysCharged': 0},
# ...

# %%
data.keys()
# Out:
# dict_keys(['instruments', 'lastTransactionID'])

# %%
instruments = data['instruments']
type(instruments)
# Out:
# list

# %%
instrument_data=[]
for item in (instruments):
    new_ob = dict(
        name = item['name'],
        item_type = item['type'],
        displayName = item['displayName'],
        pipLocation = item['pipLocation'],
        marginRate = item['marginRate']
    )
    instrument_data.append(new_ob)

# %%
for items in instruments[0:3]:
    print(items)
# Out:
# {'name': 'XAG_EUR', 'type': 'METAL', 'displayName': 'Silver/EUR', 'pipLocation': -4, 'displayPrecision': 5, 'tradeUnitsPrecision': 0, 'minimumTradeSize': '1', 'maximumTrailingStopDistance': '1.00000', 'minimumTrailingStopDistance': '0.00050', 'maximumPositionSize': '0', 'maximumOrderUnits': '500000', 'marginRate': '0.10', 'guaranteedStopLossOrderMode': 'DISABLED', 'tags': [{'type': 'KID_ASSET_CLASS', 'name': 'METAL'}, {'type': 'ASSET_CLASS', 'name': 'COMMODITY'}], 'financing': {'longRate': '-0.007', 'shortRate': '-0.0154', 'financingDaysOfWeek': [{'dayOfWeek': 'MONDAY', 'daysCharged': 1}, {'dayOfWeek': 'TUESDAY', 'daysCharged': 1}, {'dayOfWeek': 'WEDNESDAY', 'daysCharged': 1}, {'dayOfWeek': 'THURSDAY', 'daysCharged': 1}, {'dayOfWeek': 'FRIDAY', 'daysCharged': 1}, {'dayOfWeek': 'SATURDAY', 'daysCharged': 0}, {'dayOfWeek': 'SUNDAY', 'daysCharged': 0}]}}
# ...

# %%
instrument_df = pd.DataFrame(instrument_data)

# %%
instrument_df.to_pickle('instruments.pkl')
